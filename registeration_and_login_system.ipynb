# %% [markdown]
# <a href="https://colab.research.google.com/github/afifakhader/registeration-and-login-sytem-/blob/main/registeration_and_login_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
emailregex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
SpecialSym =['$', '@', '#', '%']
global data 
global db
global d 
global f
db = open("hafta.txt", "a")



def reg():

    mail = input("enter email")
    regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
    def check(mail):
         if(re.fullmatch(regex, mail)):
            print("Valid Email")
 
         else:
            print("Invalid Email")
            reg()
    check(mail)
    
    
    
    password = input ("enter a password")
    if len(password) < 5:
        print('length should be at least 5')
        reg()
            
    elif len(password) > 20:
        print('length should be not be greater than 16')
        reg()
            
    elif not any(char.isdigit() for char in password):
        print('password should have at least one numeral')
        reg()
            
    elif not any(char.isupper() for char in password):
        print('password should have at least one uppercase letter')
        reg()
            
    elif not any(char.islower() for char in password):
        print('password should have at least one lowercase letter')
        reg()
            
    elif not any(char.islower() for char in password):
        print('password should have at least one lowercase letter')
        reg()
            
    else:
        print ("valid password")
 
        db.write(mail + "," + password + "\n")
        db.close()
        home()
            
            
def login():
    db = open("hafta.txt", "r")
    mail = input("enter email")
    
    
  
    password = input ("enter a password")
    d = []
    f = []
    for i in db:
        a,b = i.split(",")
      
        b = b.strip()
        d.append(a)
        f.append(b)
    data = dict(zip(d,f))
    
    if mail not in d:
        print ("mail doesnt exist")
        home()
  
    if mail  in d:
               if password not in f or d.index(mail) != f.index(password):
                  print ("wrong password")
                  x = input("reg or forgot password")
                  if x == "reg":
                      reg()
                  elif x == "forgot password":
                      ind = d.index(mail)
                      print("your password is ",f[ind])
                  else:
                        print ("make a coorect choice")
                  
    if data.get(mail) == password:
            print("access given")
            
        
    if mail not in d:
        print ("mail doesnt exist")
        home()
  
                  
                   
                  
        
def home():
    print ("choose your action reg / login")
    choice = input ("enter choice")
    if choice == "reg":
        reg()
    elif choice == "login":
        login()
            
    else:
        print ("make a correct choice")
        home()
